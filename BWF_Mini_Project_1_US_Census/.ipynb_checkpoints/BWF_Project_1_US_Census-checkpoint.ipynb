# %%
                                    '''Deep Learning - BWF'''

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Data

# %% [markdown]
# **Loading data into DataFrame**

# %%
import glob

# Get data file names
path = r'C:\Users\DSC\Desktop\python_practice\BWF_tasks'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
us_census = pd.concat(dfs, ignore_index=True)

# %%
us_census.head()
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# ...

# %%
us_census.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %% [markdown]
# # Cleaning / Managing Data

# %% [markdown]
# **Dropping unwanted column**

# %%
us_census=us_census.drop('Unnamed: 0',axis=1)

us_census.head()
# Out:
#         State  TotalPop             Hispanic                White  \
# 0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# 0  0.03435374149659865%  $43296.35860306644    2341093M_2489527F
# ...

# %%
us_census.dtypes
# Out:
# State        object
# TotalPop      int64
# Hispanic     object
# White        object
# Black        object
# Native       object
# Asian        object
# Pacific      object
# Income       object
# GenderPop    object
# dtype: object

# %% [markdown]
# **Converting columns to suitable dtypes**

# %%
us_census['Hispanic'] = us_census['Hispanic'].str.replace('%','').astype(float)

# %%
us_census['White'] = us_census['White'].str.replace('%','').astype(float)

# %%
us_census['Black'] = us_census['Black'].str.replace('%','').astype(float)

# %%
us_census['Native'] = us_census['Native'].str.replace('%','').astype(float)

# %%
us_census['Asian'] = us_census['Asian'].str.replace('%','').astype(float)

# %%
us_census['Pacific'] = us_census['Pacific'].str.replace('%','').astype(float)

# %%
us_census['Income'] = us_census['Income'].str.replace('$','').astype(float)
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16408\462306333.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   us_census['Income'] = us_census['Income'].str.replace('$','').astype(float)

# %%
us_census = us_census.round(decimals=2)

# %%
us_census.head()
# Out:
#         State  TotalPop  Hispanic  White  Black  Native  Asian  Pacific  \
# 0     Alabama   4830620      3.75  61.88  31.25    0.45   1.05     0.03
# 1      Alaska    733375      5.91  60.91   2.85   16.39   5.45     1.06
# 2     Arizona   6641928     29.57  57.12   3.85    4.36   2.88     0.17
# 3    Arkansas   2958208      6.22  71.14  18.97    0.52   1.14     0.15
# 4  California  38421464     37.29  40.22   5.68    0.41  13.05     0.35
#
#      Income            GenderPop
# 0  43296.36    2341093M_2489527F
# 1  70354.74      384160M_349215F
# 2  54207.82    3299088M_3342840F
# 3  41935.63    1451913M_1506295F
# 4  67264.78  19087135M_19334329F

# %%
us_census.dtypes
# Out:
# State         object
# TotalPop       int64
# Hispanic     float64
# White        float64
# Black        float64
# Native       float64
# Asian        float64
# Pacific      float64
# Income       float64
# GenderPop     object
# dtype: object

# %% [markdown]
# **Splitting GenderPop Column into Male_Pop and Female_Pop**

# %%
us_census[['Male_Pop','Female_Pop']] = us_census.GenderPop.str.split('_', expand=True)

# %%
us_census = us_census.drop('GenderPop',axis=1)

# %%
us_census.head()
# Out:
#         State  TotalPop  Hispanic  White  Black  Native  Asian  Pacific  \
# 0     Alabama   4830620      3.75  61.88  31.25    0.45   1.05     0.03
# 1      Alaska    733375      5.91  60.91   2.85   16.39   5.45     1.06
# 2     Arizona   6641928     29.57  57.12   3.85    4.36   2.88     0.17
# 3    Arkansas   2958208      6.22  71.14  18.97    0.52   1.14     0.15
# 4  California  38421464     37.29  40.22   5.68    0.41  13.05     0.35
#
#      Income   Male_Pop Female_Pop
# 0  43296.36   2341093M   2489527F
# 1  70354.74    384160M    349215F
# 2  54207.82   3299088M   3342840F
# 3  41935.63   1451913M   1506295F
# 4  67264.78  19087135M  19334329F

# %% [markdown]
# **making Male_Pop and Female_Pop column suitable for future use**

# %%
us_census['Male_Pop'] = us_census['Male_Pop'].str.replace('M','.0')
us_census['Female_Pop'] = us_census['Female_Pop'].str.replace('F','.0')

# %%
us_census.dtypes
# Out:
# State          object
# TotalPop        int64
# Hispanic      float64
# White         float64
# Black         float64
# Native        float64
# Asian         float64
# Pacific       float64
# Income        float64
# Male_Pop       object
# Female_Pop     object
# dtype: object

# %% [markdown]
# **Dropping Duplicate rows**

# %%
us_census = us_census.drop_duplicates(subset=['State'])

# %%
us_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 59
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   State       51 non-null     object
#  1   TotalPop    51 non-null     int64
#  2   Hispanic    51 non-null     float64
#  3   White       51 non-null     float64
#  4   Black       51 non-null     float64
#  5   Native      51 non-null     float64
#  6   Asian       51 non-null     float64
#  7   Pacific     47 non-null     float64
#  8   Income      51 non-null     float64
#  9   Male_Pop    51 non-null     object
#  10  Female_Pop  51 non-null     object
# dtypes: float64(7), int64(1), object(3)
# memory usage: 4.8+ KB

# %% [markdown]
# **Converting Male_Pop and Female_Pop into suitable dtypes**

# %%
us_census['Male_Pop'] = us_census['Male_Pop'].astype(float)
us_census['Female_Pop'] = us_census['Female_Pop'].astype(float)

# %%
us_census.dtypes
# Out:
# State          object
# TotalPop        int64
# Hispanic      float64
# White         float64
# Black         float64
# Native        float64
# Asian         float64
# Pacific       float64
# Income        float64
# Male_Pop      float64
# Female_Pop    float64
# dtype: object

# %%
us_census['Male_Pop'] = us_census['Male_Pop'].astype(int)
us_census['Female_Pop'] = us_census['Female_Pop'].astype(int)

# %%
us_census.dtypes
# Out:
# State          object
# TotalPop        int64
# Hispanic      float64
# White         float64
# Black         float64
# Native        float64
# Asian         float64
# Pacific       float64
# Income        float64
# Male_Pop        int32
# Female_Pop      int32
# dtype: object

# %% [markdown]
# **Filling null values in Female_Pop column**

# %%
us_census['Female_Pop'] = us_census['TotalPop'] - us_census['Male_Pop']

# %%
us_census['Female_Pop']
# Out:
# 0      2489527
# 1       349215
# 2      3342840
# 3      1506295
# 4     19334329
# 5      2630239
# 7      1841615
# 8       478041
# 9       340810
# 10    10045763
# 11     5123362
# 13      696428
# 14      806083
# 15     6556862
# 16     3333382
# 17     1558931
# 19     1453125
# 20     2233145
# 21     2364097
# 22      679019
# 23     3057895
# 25     3455936
# 26     5038598
# 27     2727005
# 28     1536358
# 29     3081445
# 31      504536
# 32      939759
# 33     1390901
# 34      670717
# 35     4561386
# 37     1051703
# 38    10131373
# 39     5049925
# 40      353677
# 41     5913084
# 43     1942789
# 44     1990780
# 45     6534215
# 46     1869213
# 47      543273
# 49     2455167
# 50      419713
# 51     3331859
# 52    13367298
# 53     1444150
# 55      318031
# 56     4195682
# 57     3497739
# 58      937789
# 59     2890732
# Name: Female_Pop, dtype: int64

# %%
us_census
# Out:
#                    State  TotalPop  Hispanic  White  Black  Native  Asian  \
# 0                Alabama   4830620      3.75  61.88  31.25    0.45   1.05
# 1                 Alaska    733375      5.91  60.91   2.85   16.39   5.45
# 2                Arizona   6641928     29.57  57.12   3.85    4.36   2.88
# 3               Arkansas   2958208      6.22  71.14  18.97    0.52   1.14
# 4             California  38421464     37.29  40.22   5.68    0.41  13.05
# 5               Colorado   5278906     20.78  69.90   3.55    0.57   2.66
# 7            Connecticut   3593222     15.60  67.68  10.35    0.13   4.02
# 8               Delaware    926454      8.82  64.63  20.74    0.26   3.27
# 9   District of Columbia    647484      9.17  33.10  51.78    0.20   3.38
# 10               Florida  19645772     21.34  59.08  15.17    0.21   2.28
# 11               Georgia  10006693      8.42  54.29  32.09    0.19   3.10
# 13                Hawaii   1406299      9.19  25.03   2.05    0.14  36.59
# ...

# %%
plt.scatter(x=us_census['Female_Pop'],y=us_census['Income'])
plt.title('Average Income vs Female Population')
plt.xlabel('Female Population (in millions)')
plt.ylabel('Average Income of States')
plt.show()

# %%
us_census = us_census.fillna(0)

# %%
plt.hist(us_census['Native'])
plt.show()
